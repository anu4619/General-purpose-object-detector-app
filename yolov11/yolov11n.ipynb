# %%
# !pip install ultralytics
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 45.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 108.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 82.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 49.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 11.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 89.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
from ultralytics import YOLO
from PIL import Image

model = YOLO("yolo11n.pt")
image_path = "/content/2022-02-04-test_image.jpg"
image = Image.open(image_path)

image.show()


results = model(image_path)

# Display the results
results[0].show()
# Out:
# Creating new Ultralytics Settings v0.0.6 file ✅
# View Ultralytics Settings with 'yolo settings' or at '/root/.config/Ultralytics/settings.json'
# Update Settings with 'yolo settings key=value', i.e. 'yolo settings runs_dir=path/to/dir'. For help see https://docs.ultralytics.com/quickstart/#ultralytics-settings.
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 321MB/s]
# image 1/1 /content/2022-02-04-test_image.jpg: 416x640 2 persons, 1 bicycle, 1 car, 399.4ms
# Speed: 17.6ms preprocess, 399.4ms inference, 31.7ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Perform object detection on an image
results = model("/content/test_video.mp4", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/112) /content/test_video.mp4: 384x640 2 persons, 7 cars, 140.1ms
# video 1/1 (frame 2/112) /content/test_video.mp4: 384x640 2 persons, 8 cars, 134.3ms
# video 1/1 (frame 3/112) /content/test_video.mp4: 384x640 2 persons, 6 cars, 124.5ms
# video 1/1 (frame 4/112) /content/test_video.mp4: 384x640 2 persons, 6 cars, 127.6ms
# video 1/1 (frame 5/112) /content/test_video.mp4: 384x640 2 persons, 4 cars, 124.3ms
# ...

# %%
from ultralytics import YOLO

    # Load your trained model (replace 'yolo11n.pt' with your model path)
model = YOLO("yolo11n.pt")

    # Export the model to ONNX format
model.export(format="onnx")
# Out:
# Ultralytics 8.3.135 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# 💡 ProTip: Export to OpenVINO format for best performance on Intel CPUs. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from 'yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
# requirements: Ultralytics requirements ['onnx>=1.12.0,<1.18.0', 'onnxslim>=0.1.46', 'onnxruntime'] not found, attempting AutoUpdate...
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.0/16.0 MB 180.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 146.2/146.2 kB 184.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 16.4/16.4 MB 179.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 147.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 180.3 MB/s eta 0:00:00
# ...
#
# ...

# %%
# !pip install tf2onnx tensorflow
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 455.8/455.8 kB 18.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 162.1/162.1 kB 10.3 MB/s eta 0:00:00
# ...
#   Attempting uninstall: protobuf
#     Found existing installation: protobuf 5.29.4
#     Uninstalling protobuf-5.29.4:
#       Successfully uninstalled protobuf-5.29.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-metadata 1.17.1 requires protobuf<6.0.0,>=4.25.2; python_version >= "3.11", but you have protobuf 3.20.3 which is incompatible.
# ydf 0.11.0 requires protobuf<6.0.0,>=5.29.1, but you have protobuf 3.20.3 which is incompatible.
# grpcio-status 1.71.0 requires protobuf<6.0dev,>=5.26.1, but you have protobuf 3.20.3 which is incompatible.
# ...

# %%
from ultralytics import YOLO

# Load model
model = YOLO("/content/yolo11n.pt")

# Export to TFLite
model.export(format="tflite", int8=True)  # or int8=True for quantized
# Out:
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# 💡 ProTip: Export to OpenVINO format for best performance on Intel CPUs. Learn more at https://docs.ultralytics.com/integrations/openvino/
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from '/content/yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
# requirements: Ultralytics requirements ['sng4onnx>=1.0.1', 'onnx_graphsurgeon>=0.3.26', 'ai-edge-litert>=1.2.0', 'onnx>=1.12.0,<1.18.0', 'onnx2tf>=1.26.3', 'onnxslim>=0.1.53', 'onnxruntime'] not found, attempting AutoUpdate...
#
# requirements: AutoUpdate success ✅ 4.7s
# WARNING ⚠️ requirements: Restart runtime or rerun command for updates to take effect
#
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv8n model
model = YOLO("yolov8n.pt")

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 107MB/s]
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
image_path = "/content/2022-02-04-test_image.jpg"
image = Image.open(image_path)

image.show()


results = model(image_path)

# Display the results
results[0].show()
# Out:
# image 1/1 /content/2022-02-04-test_image.jpg: 416x640 2 persons, 1 bicycle, 1 car, 2 dogs, 147.2ms
# Speed: 4.5ms preprocess, 147.2ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov8n.pt")

# Perform object detection on an image
results = model("/content/test_video.mp4", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/112) /content/test_video.mp4: 384x640 2 persons, 8 cars, 149.2ms
# video 1/1 (frame 2/112) /content/test_video.mp4: 384x640 2 persons, 5 cars, 1 traffic light, 138.8ms
# video 1/1 (frame 3/112) /content/test_video.mp4: 384x640 2 persons, 7 cars, 162.5ms
# video 1/1 (frame 4/112) /content/test_video.mp4: 384x640 2 persons, 6 cars, 1 truck, 139.2ms
# ...

# %%
from ultralytics import YOLO

# Load model
model = YOLO("/content/yolov8n.pt")

# Export to TFLite
model.export(format="tflite", int8=True)  # or int8=True for quantized
# Out:
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
#
# PyTorch: starting from '/content/yolov8n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (6.2 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.53...
# ONNX: export success ✅ 2.1s, saved as '/content/yolov8n.onnx' (12.3 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 721.1±164.8 MB/s, size: 54.0 KB)
# Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLOv5n model
model = YOLO("yolov5n.pt")

# Display model information (optional)
model.info()

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# Run inference with the YOLOv5n model on the 'bus.jpg' image
results = model("/content/2022-02-04-test_image.jpg")
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# YOLOv5n summary: 153 layers, 2,654,816 parameters, 0 gradients, 7.8 GFLOPs
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
image_path = "/content/2022-02-04-test_image.jpg"
image = Image.open(image_path)

image.show()


results = model(image_path)

# Display the results
results[0].show()
# Out:
# image 1/1 /content/2022-02-04-test_image.jpg: 416x640 2 persons, 1 bicycle, 2 cars, 160.8ms
# Speed: 4.2ms preprocess, 160.8ms inference, 1.5ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolov5n.pt")

# Perform object detection on an image
results = model("/content/test_video.mp4", save=True)
# Out:
# PRO TIP 💡 Replace 'model=yolov5n.pt' with new 'model=yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
#
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/112) /content/test_video.mp4: 384x640 2 persons, 5 cars, 214.7ms
# video 1/1 (frame 2/112) /content/test_video.mp4: 384x640 2 persons, 5 cars, 124.3ms
# ...

# %%
from ultralytics import YOLO

# Load model
model = YOLO("/content/yolov5n.pt")

# Export to TFLite
model.export(format="tflite", int8=True)  # or int8=True for quantized
# Out:
# PRO TIP 💡 Replace 'model=/content/yolov5n.pt' with new 'model=/content/yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# YOLOv5n summary (fused): 84 layers, 2,649,200 parameters, 0 gradients, 7.7 GFLOPs
#
# PyTorch: starting from '/content/yolov5nu.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.3 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.53...
# ONNX: export success ✅ 1.6s, saved as '/content/yolov5nu.onnx' (10.4 MB)
# ...

# %%
from ultralytics import YOLO

# Load a COCO-pretrained YOLO11n model
model = YOLO("yolo11n.pt")

# Train the model on the COCO8 example dataset for 100 epochs
results = model.train(data="coco8.yaml", epochs=100, imgsz=640)

# Run inference with the YOLO11n model on the 'bus.jpg' image
results = model("/content/2022-02-04-test_image.jpg")
# Out:
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# ...

# %%
image_path = "/content/2022-02-04-test_image.jpg"
image = Image.open(image_path)

image.show()


results = model(image_path)

# Display the results
results[0].show()
# Out:
# image 1/1 /content/2022-02-04-test_image.jpg: 416x640 2 persons, 1 bicycle, 1 car, 284.0ms
# Speed: 10.9ms preprocess, 284.0ms inference, 2.1ms postprocess per image at shape (1, 3, 416, 640)
# <PIL.Image.Image image mode=RGB size=800x500>

# %%
from ultralytics import YOLO

# Load a model
model = YOLO("yolo11n.pt")

# Perform object detection on an image
results = model("/content/test_video.mp4", save=True)
# Out:
# WARNING ⚠️
# inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# video 1/1 (frame 1/112) /content/test_video.mp4: 384x640 2 persons, 7 cars, 131.1ms
# video 1/1 (frame 2/112) /content/test_video.mp4: 384x640 2 persons, 8 cars, 132.5ms
# video 1/1 (frame 3/112) /content/test_video.mp4: 384x640 2 persons, 6 cars, 134.9ms
# video 1/1 (frame 4/112) /content/test_video.mp4: 384x640 2 persons, 6 cars, 132.0ms
# video 1/1 (frame 5/112) /content/test_video.mp4: 384x640 2 persons, 4 cars, 145.5ms
# ...

# %%
from ultralytics import YOLO

# Load model
model = YOLO("/content/yolo11n.pt")

# Export to TFLite
model.export(format="tflite", int8=True)  # or int8=True for quantized
# Out:
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# WARNING ⚠️ INT8 export requires a missing 'data' arg for calibration. Using default 'data=coco8.yaml'.
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
#
# PyTorch: starting from '/content/yolo11n.pt' with input shape (1, 3, 640, 640) BCHW and output shape(s) (1, 84, 8400) (5.4 MB)
#
# TensorFlow SavedModel: starting export with tensorflow 2.18.0...
#
# ONNX: starting export with onnx 1.17.0 opset 19...
# ONNX: slimming with onnxslim 0.1.53...
# ONNX: export success ✅ 2.0s, saved as '/content/yolo11n.onnx' (10.3 MB)
# TensorFlow SavedModel: collecting INT8 calibration images from 'data=coco8.yaml'
# Fast image access ✅ (ping: 0.0±0.0 ms, read: 925.1±452.9 MB/s, size: 54.0 KB)
# Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
# ...

# %%
from ultralytics import YOLO

# Load your trained YOLOv8n model
# Replace 'path/to/your/yolov8n.pt' with the actual path to your trained model weights
model = YOLO("content/yolov8n.pt")

# Evaluate the model on your validation dataset
# Replace 'path/to/your/coco8.yaml' with the actual path to your data YAML file
results = model.val(data="coco8.yaml")
# Out:
# ...
# 100%|██████████| 6.25M/6.25M [00:00<00:00, 204MB/s]
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv8n summary (fused): 72 layers, 3,151,904 parameters, 0 gradients, 8.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1016.8±361.6 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.02it/s]
#                    all          4         17      0.621      0.833      0.888       0.63
#                 person          3         10      0.721        0.5      0.519      0.269
#                    dog          1          1       0.37          1      0.995      0.597
#                  horse          1          2      0.751          1      0.995      0.631
# ...

# %%
from ultralytics import YOLO

# Load your trained YOLOv8n model
# Replace 'path/to/your/yolov8n.pt' with the actual path to your trained model weights
model = YOLO("content/yolov5n.pt")

# Evaluate the model on your validation dataset
# Replace 'path/to/your/coco8.yaml' with the actual path to your data YAML file
results = model.val(data="coco8.yaml")
# Out:
# PRO TIP 💡 Replace 'model=content/yolov5n.pt' with new 'model=content/yolov5nu.pt'.
# YOLOv5 'u' models are trained with https://github.com/ultralytics/ultralytics and feature improved performance vs standard YOLOv5 models trained with https://github.com/ultralytics/yolov5.
#
# ...
# 100%|██████████| 5.31M/5.31M [00:00<00:00, 167MB/s]
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLOv5n summary (fused): 84 layers, 2,649,200 parameters, 0 gradients, 7.7 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 992.3±364.0 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:01<00:00,  1.05s/it]
#                    all          4         17      0.802      0.667      0.901      0.628
# ...

# %%
from ultralytics import YOLO

# Load your trained YOLOv8n model
# Replace 'path/to/your/yolov8n.pt' with the actual path to your trained model weights
model = YOLO("content/yolo11n.pt")

# Evaluate the model on your validation dataset
# Replace 'path/to/your/coco8.yaml' with the actual path to your data YAML file
results = model.val(data="coco8.yaml")
# Out:
# ...
# 100%|██████████| 5.35M/5.35M [00:00<00:00, 231MB/s]
# Ultralytics 8.3.140 🚀 Python-3.11.12 torch-2.6.0+cu124 CPU (Intel Xeon 2.20GHz)
# YOLO11n summary (fused): 100 layers, 2,616,248 parameters, 0 gradients, 6.5 GFLOPs
# val: Fast image access ✅ (ping: 0.0±0.0 ms, read: 1075.1±212.9 MB/s, size: 54.0 KB)
# val: Scanning /content/datasets/coco8/labels/val.cache... 4 images, 0 backgrounds, 0 corrupt: 100%|██████████| 4/4 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 1/1 [00:00<00:00,  1.22it/s]
#                    all          4         17       0.57       0.85      0.847      0.632
#                 person          3         10      0.557        0.6      0.585      0.272
#                    dog          1          1      0.548          1      0.995      0.697
#                  horse          1          2      0.531          1      0.995      0.674
# ...
